# %% [markdown]
# # **İngiltere'deki İkinci El Ford Markalı Arabaların Analizi**

# %% [markdown]
# 1.   Numpy: Dizi, vektör, matris...
# 2.   Pandas: Veri işlemek.
# 3.   MatPlotlib: Veri görselleştirmek.
# 4.   Seaborn: Matplotlib'in daha derin kullanımı.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataFrame=pd.read_excel("FordList.xlsx")

# %% [markdown]
# # **Okuttuğum veri kümesinin ilk altı satırını istedim.**

# %%
dataFrame.head(6)
# Out:
#      model    year    price transmission  ...  fuelType    tax   mpg  engineSize
# 0   Fiesta  2017.0  12000.0    Automatic  ...    Petrol  150.0  57.7         1.0
# 1    Focus  2018.0  14000.0       Manual  ...    Petrol  150.0  57.7         1.0
# 2    Focus  2017.0  13000.0       Manual  ...    Petrol  150.0  57.7         1.0
# 3   Fiesta  2019.0  17500.0       Manual  ...    Petrol  145.0  40.3         1.5
# 4   Fiesta  2019.0  16500.0    Automatic  ...    Petrol  145.0  48.7         1.0
# 5   Fiesta  2015.0  10500.0       Manual  ...    Petrol  145.0   NaN         1.6
#
# [6 rows x 9 columns]

# %% [markdown]
# # **Okuttuğum veri kümesinin son altı satırını istedim.**

# %%
dataFrame.tail(6)
# Out:
#          model    year   price transmission  ...  fuelType    tax   mpg  engineSize
# 17957    C-MAX  2016.0  9299.0       Manual  ...    Diesel   20.0  68.9         1.5
# 17958   Fiesta  2016.0  7999.0       Manual  ...    Petrol  125.0  54.3         1.2
# 17959    B-MAX  2017.0  8999.0       Manual  ...    Petrol  150.0  47.1         1.4
# 17960    B-MAX  2014.0  7499.0       Manual  ...    Petrol   30.0  57.7         1.0
# 17961    Focus  2015.0  9999.0       Manual  ...    Diesel   20.0  67.3         1.6
# 17962       KA  2018.0  8299.0       Manual  ...    Petrol  145.0  57.7         1.2
#
# [6 rows x 9 columns]

# %% [markdown]
# **Boş değerleri sildim.**

# %%
dataFrame.dropna(how="any",inplace=True)

# %%
dataFrame.dropna(how="all",inplace=True)

# %% [markdown]
# # [Boş değerimin kalıp kalmadığını görmek için toplamını aldım.]

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# # **Veri kümesinin bilgilerine ulaştım**

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17589 entries, 0 to 17962
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17589 non-null  object
#  1   year          17589 non-null  float64
#  2   price         17589 non-null  float64
#  3   transmission  17589 non-null  object
#  4   mileage       17589 non-null  float64
#  5   fuelType      17589 non-null  object
#  6   tax           17589 non-null  float64
#  7   mpg           17589 non-null  float64
#  8   engineSize    17589 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# # **Boyutuna ulaştım.**

# %%
dataFrame.shape
# Out:
# (17589, 9)

# %%
dataFrame.head(10)
# Out:
#         model    year    price transmission  ...  fuelType    tax   mpg  engineSize
# 0      Fiesta  2017.0  12000.0    Automatic  ...    Petrol  150.0  57.7         1.0
# 1       Focus  2018.0  14000.0       Manual  ...    Petrol  150.0  57.7         1.0
# 2       Focus  2017.0  13000.0       Manual  ...    Petrol  150.0  57.7         1.0
# 3      Fiesta  2019.0  17500.0       Manual  ...    Petrol  145.0  40.3         1.5
# 4      Fiesta  2019.0  16500.0    Automatic  ...    Petrol  145.0  48.7         1.0
# 6        Puma  2019.0  22500.0       Manual  ...    Petrol  145.0  50.4         1.0
# 7      Fiesta  2017.0   9000.0       Manual  ...    Petrol  145.0  54.3         1.2
# 9       Focus  2018.0  10000.0       Manual  ...    Petrol  145.0  61.4         1.0
# 10     Fiesta  2018.0  11561.0       Manual  ...    Petrol  145.0  56.5         1.0
# 11   EcoSport  2018.0  13500.0       Manual  ...    Petrol  145.0  54.3         1.0
#
# [10 rows x 9 columns]

# %%
sns.countplot(dataFrame["transmission"])

# %%
sns.countplot(dataFrame["fuelType"])

# %%
print(dataFrame["model"].value_counts() / len(dataFrame))
sns.countplot(y = dataFrame["model"])
# Out:
#  Fiesta                   0.367446
#  Focus                    0.256297
#  Kuga                     0.123771
#  EcoSport                 0.064188
#  C-MAX                    0.030076
#  Ka+                      0.030019
#  Mondeo                   0.029166
#  B-MAX                    0.019671
#  S-MAX                    0.016658
#  Grand C-MAX              0.013531
#  Galaxy                   0.012792
#  Edge                     0.011712
#  KA                       0.010802
#  Puma                     0.004491
#  Grand Tourneo Connect    0.003298
#  Tourneo Custom           0.003070
#  Tourneo Connect          0.001819
#  Fusion                   0.000796
#  Mustang                  0.000171
#  Streetka                 0.000114
#  Escort                   0.000057
#  Transit Tourneo          0.000057
# Name: model, dtype: float64

# %% [markdown]
# # **Nümerik değerlere çevirdim.**

# %%
dataFrame_new = pd.get_dummies(dataFrame)
dataFrame_new.head()
# Out:
#      year    price  mileage  ...  fuelType_Diesel  fuelType_Hybrid  fuelType_Petrol
# 0  2017.0  12000.0  15944.0  ...                0                0                1
# 1  2018.0  14000.0   9083.0  ...                0                0                1
# 2  2017.0  13000.0  12456.0  ...                0                0                1
# 3  2019.0  17500.0  10460.0  ...                0                0                1
# 4  2019.0  16500.0   1482.0  ...                0                0                1
#
# [5 rows x 34 columns]

# %% [markdown]
# ![Correlation-Coefficient-Formula.jpg](data:image/jpeg;base64,...)

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dataFrame.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage      -0.538553
# mpg          -0.310352
# engineSize    0.351839
# tax           0.416673
# year          0.660153
# price         1.000000
# Name: price, dtype: float64

# %% [markdown]
# # **Fiyat dağılım grafiğini oluşturdum.**

# %%
plt.figure(figsize=(13,7))
sns.distplot(dataFrame_new["price"])
plt.show()

# %% [markdown]
# # **Verilerin yıla göre dağılımı:**

# %%
plt.figure(figsize=(15,6))
sns.countplot(dataFrame_new["year"])

# %%
ydd=dataFrame.sort_values("price",ascending=False).iloc[:]

# %%
ydd.groupby("year").mean()["price"]
# Out:
# year
# 1996.0     3000.000000
# 1998.0     2699.000000
# 2000.0     1995.000000
# 2002.0     1928.333333
# 2003.0     2063.000000
# 2004.0     1436.000000
# 2005.0     1593.000000
# 2006.0     2202.615385
# 2007.0     2351.884615
# 2008.0     2531.377358
# 2009.0     3546.104651
# 2010.0     4009.734375
# 2011.0     4949.222222
# 2012.0     5624.300000
# 2013.0     6670.385906
# 2014.0     7548.698089
# 2015.0     8782.787218
# 2016.0    10625.031579
# 2017.0    11930.800997
# 2018.0    13079.721801
# 2019.0    17028.821830
# 2020.0    20046.258197
# Name: price, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ![Ekran Görüntüsü (188).png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split
X = dataFrame_new.drop(columns=["price"],axis=1)
y=dataFrame_new.iloc[:,1:2].values
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.20, random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14071, 33)
# (3518, 33)
# (14071, 1)
# (3518, 1)

# %% [markdown]
# 1-KOD AŞAMALARI:
# 2-ALGORİTMA
# 3-CROSS VALIDATION
# 4-METRİKLER
# 5-LDA
# 6-LDA SONRASI TEKRAR ALGORİTMA VE SONUCU KONTROL ETME

# %% [markdown]
# LINEAR REGRESYON

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
score_lr=cross_val_score(lr,X,y,cv=5)
print(score_lr)
print(score_lr.mean())
# Out:
# [0.84033694 0.83257506 0.83821653 0.8207615  0.73707225]
# 0.8137924543168402

# %% [markdown]
# ![Ekran Görüntüsü (189).png](data:image/png;base64,...)

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2_score:', metrics.r2_score (y_test, y_pred))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error: 3236413.607994663
# Root Mean Squared Error: 1799.0035041640867
# r2_score: 0.8410290873010744
# Mean Absolute Error: 1347.9181385504576

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
print(cross_val_score(lr,X,y,cv=5))
print(score_lr.mean())
# Out:
# [0.84033694 0.83257506 0.83821653 0.8207615  0.73707225]
# 0.8137924543168402

# %%
plt.scatter(X_train,y_train)
plt.plot(X_test, lr.predict(X_test),"g-*")
plt.show()

# %% [markdown]
# DESICION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
dtr=DecisionTreeClassifier()
dtr.fit(X_train,y_train)
y_pred=dtr.predict(X_test)

# %%
score_dtr=cross_val_score(dtr,X,y,cv=5)
print(score_dtr)
print(score_dtr.mean())
# Out:
# [0.02160318 0.03183627 0.02728823 0.02444571 0.01734433]
# 0.02450354430514792

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2_score:', metrics.r2_score (y_test, y_pred))
# Out:
# Mean Absolute Error: 1507.6202387720296
# Mean Squared Error: 4528303.418988061
# Root Mean Squared Error: 2127.981066407326
# r2_score: 0.777572147850336

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
dtr=DecisionTreeClassifier()
dtr.fit(X_train,y_train)
y_pred_dtr=dtr.predict(X_test)

# %%
score_dtr=cross_val_score(dtr,X,y,cv=5)
print(score_dtr)
print(score_dtr.mean())
# Out:
# [0.02188744 0.03069926 0.02728823 0.02529847 0.01734433]
# 0.02450354430514792

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators=20)
forest.fit(X_train,y_train)
y_pred=forest.predict(X_test)

# %%
score_forest=cross_val_score(forest,X,y,cv=5)
print(score_forest)
print(score_forest.mean())
# Out:
# [0.91346944 0.92212834 0.9188618  0.91552133 0.90955924]
# 0.9159080325807276

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2_score:', metrics.r2_score (y_test, y_pred))
# Out:
# Mean Absolute Error: 1310.5094780584207
# Mean Squared Error: 3210616.1859053927
# Root Mean Squared Error: 1791.8192391827342
# r2_score: 0.8422962429342976

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
forest = RandomForestRegressor(n_estimators=20)
forest.fit(X_train,y_train)
y_predt=forest.predict(X_test)

# %%
score_forest=cross_val_score(forest,X,y,cv=5)
print(score_forest)
print(score_forest.mean())
# Out:
# [0.91241379 0.92000307 0.91824912 0.91527917 0.91133873]
# 0.9154567767060676

# %% [markdown]
# BOOSTİNG

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred_gbr=gbr.predict(X_test)

# %%
score_gbr=cross_val_score(gbr,X,y,cv=5)
print(score_gbr)
print(score_gbr.mean())
# Out:
# [0.90612675 0.91555636 0.91314461 0.90159418 0.90340099]
# 0.9079645787534154

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_gbr))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_gbr))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_gbr)))
print('r2_score:', metrics.r2_score (y_test, y_pred_gbr))
# Out:
# Mean Absolute Error: 1100.0106915236288
# Mean Squared Error: 2173702.246202929
# Root Mean Squared Error: 1474.348074981932
# r2_score: 0.8932289033883106

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
gbr=GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred_gbr=gbr.predict(X_test)

# %%
score_gbr=cross_val_score(gbr,X,y,cv=5)
print(score_gbr)
print(score_gbr.mean())
# Out:
# [0.90612675 0.91555438 0.91314461 0.90161803 0.90308747]
# 0.9079062500660054

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred_knn=knn.predict(X_test)

# %%
score_knn=cross_val_score(knn,X,y,cv=5)
print(score_knn)
print(score_knn.mean())
# Out:
# [0.00397953 0.00682206 0.0059693  0.00568505 0.00284333]
# 0.005059854652210663

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_knn))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_knn))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn)))
print('r2_score:', metrics.r2_score (y_test, y_pred_knn))
# Out:
# Mean Absolute Error: 1711.1714042069357
# Mean Squared Error: 5037347.395395111
# Root Mean Squared Error: 2244.403572309381
# r2_score: 0.7525681788479128

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred_knn=knn.predict(X_test)

# %%
score_knn=cross_val_score(knn,X,y,cv=5)
print(score_knn)
print(score_knn.mean())
# Out:
# [0.00397953 0.00682206 0.0059693  0.00568505 0.00284333]
# 0.005059854652210663

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train,y_train)
y_pred_svr=svr.predict(X_test)

# %%
score_svr=cross_val_score(svr,X,y,cv=5)
print(score_svr)
print(score_svr.mean())
# Out:
# [ 0.11311369  0.10683255  0.01276196 -0.05570205  0.13119864]
# 0.06164095848967797

# %%
y_pred=svr.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2_score:', metrics.r2_score (y_test, y_pred))
# Out:
# Mean Absolute Error: 2187.7308095671115
# Mean Squared Error: 10782883.564013889
# Root Mean Squared Error: 3283.7301295955926
# r2_score: 0.4703505023390204

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
score_svr=cross_val_score(svr,X,y,cv=5)
print(score_svr)
print(score_svr.mean())
# Out:
# [ 0.11311369  0.10683255  0.01276196 -0.05570205  0.13119864]
# 0.06164095848967797

# %% [markdown]
# XGBOOST

# %%
from xgboost import XGBRegressor
xgbr=XGBRegressor()
xgbr.fit(X_train,y_train)
y_pred_xgbr=xgbr.predict(X_test)
# Out:
# [12:19:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgbr.score(X_test,y_test)
# Out:
# 0.8932863864581515

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test, y_pred_xgbr)
mse=mean_squared_error(y_test, y_pred_xgbr)
rs=r2_score(y_test,y_pred_xgbr)
print(mae,mse,rs)
# Out:
# 1100.354436322462 2172531.975577292 0.8932863864581515

# %%
xgbr.score(X_test,y_test)
# Out:
# 0.8932863864581515

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
xgbr.score(X_test,y_test)
# Out:
# 0.8932863864581515

# %% [markdown]
# TENSORFLOW

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model= Sequential()
model.add(Dense(10,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(1))
model.compile(optimizer="adam",loss="mse")

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 57/57 [==============================] - 1s 7ms/step - loss: 168000137.6552 - val_loss: 168737648.0000
# Epoch 2/300
# 57/57 [==============================] - 0s 2ms/step - loss: 170152106.2069 - val_loss: 168724368.0000
# Epoch 3/300
# 57/57 [==============================] - 0s 2ms/step - loss: 169070296.2759 - val_loss: 168709920.0000
# Epoch 4/300
# 57/57 [==============================] - 0s 2ms/step - loss: 169699297.9310 - val_loss: 168688224.0000
# Epoch 5/300
# 57/57 [==============================] - 0s 2ms/step - loss: 170367448.2759 - val_loss: 168654416.0000
# Epoch 6/300
# 57/57 [==============================] - 0s 2ms/step - loss: 171278672.2759 - val_loss: 168591488.0000
# Epoch 7/300
# 57/57 [==============================] - 0s 2ms/step - loss: 169280319.7241 - val_loss: 168479120.0000
# Epoch 8/300
# 57/57 [==============================] - 0s 2ms/step - loss: 169384627.8621 - val_loss: 168294512.0000
# Epoch 9/300
# ...

# %%
losedata=pd.DataFrame(model.history.history)
losedata.head()
# Out:
#           loss     val_loss
# 0  170031936.0  168737648.0
# 1  170014720.0  168724368.0
# 2  170001328.0  168709920.0
# 3  169983664.0  168688224.0
# 4  169956576.0  168654416.0

# %%
losedata.plot()

# %%
predict=model.predict(X_test)
predict
# Out:
# array([[10698.39 ],
#        [16366.317],
#        [10438.303],
#        ...,
#        [11019.621],
#        [16236.706],
#        [21995.53 ]], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test, predict)
mse=mean_squared_error(y_test, predict)
rs=r2_score(y_test,predict)
print(mae,mse,rs)
# Out:
# 1143.2088483557775 2326167.534006105 0.8857398896549908

# %%
dataFrame_new.describe()
# Out:
#                year         price  ...  fuelType_Hybrid  fuelType_Petrol
# count  17589.000000  17589.000000  ...     17589.000000     17589.000000
# mean    2016.871681  12211.959577  ...         0.001251         0.677355
# std        2.008502   4542.757416  ...         0.035345         0.467501
# min     1996.000000    495.000000  ...         0.000000         0.000000
# 25%     2016.000000   8999.000000  ...         0.000000         0.000000
# 50%     2017.000000  11290.000000  ...         0.000000         1.000000
# 75%     2018.000000  15270.000000  ...         0.000000         1.000000
# max     2020.000000  54995.000000  ...         1.000000         1.000000
#
# [8 rows x 34 columns]

# %%
plt.scatter(y_test,predict)
plt.plot(y_test,y_test,"g-*")

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test, predict)
mse=mean_squared_error(y_test, predict)
rs=r2_score(y_test,predict)
print(mae,mse,rs)
# Out:
# 1143.2088483557775 2326167.534006105 0.8857398896549908
